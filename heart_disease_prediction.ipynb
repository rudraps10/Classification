# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Heart_Disease_and_Hospitals.csv')

# %%
df.head()
# Out:
#         full_name  age country          state  blood_pressure  cholesterol  \
# 0   Alice Johnson   21     USA           Utah      138.068129   270.564349
# 1    Bob Williams   44     USA   North Dakota      100.383639   160.910030
# 2    Oliver Jones   22     USA           Iowa      145.618318   208.490251
# 3     Quinn Davis   19     USA      Louisiana      152.577870   348.153738
# 4  Alice Martinez   64     USA  Massachusetts      111.793570   200.628925
#
#          bmi  glucose_level  gender first_name last_name  \
# 0  36.101427      63.487954  Female      Alice   Johnson
# 1  14.330471     187.008977  Female        Bob  Williams
# 2  20.277098      35.903576  Female     Oliver     Jones
# 3  62.712693      31.495166  Female      Quinn     Davis
# 4  14.468485     154.513129  Female      Alice  Martinez
#
#                        hospital       treatment  \
# 0            Starlight Hospital   Physiotherapy
# 1           Maple Leaf Hospital      Counseling
# 2      Crossroads Health Center      Medication
# 3  Springfield General Hospital      Counseling
# 4          Valley View Hospital  Rehabilitation
#
#                   treatment_date  heart_disease
# 0  2021-07-07 21:23:23.542872956              1
# 1  2023-09-13 07:31:37.167014532              0
# 2  2019-11-22 03:56:29.389793943              0
# 3  2021-10-09 23:10:16.253672680              1
# 4  2018-03-16 04:43:59.950843739              1

# %%
df.tail()
# Out:
#             full_name  age country           state  blood_pressure  \
# 9995  Frank Rodriguez   40     USA         Vermont      152.854412
# 9996       Liam Davis   65     USA        Arkansas       98.406611
# 9997      Isaac Smith   69     USA     Mississippi       56.641116
# 9998       Liam Brown   62     USA  South Carolina      203.765312
# 9999   Nina Rodriguez   55     USA         Indiana      141.987528
#
#       cholesterol        bmi  glucose_level  gender first_name  last_name  \
# 9995   192.077767  41.994394      13.641234    Male      Frank  Rodriguez
# 9996   345.665055  21.462140     191.357187  Female       Liam      Davis
# 9997   202.976311   8.743848      21.214973  Female      Isaac      Smith
# 9998   286.074047  28.831543     -50.428094  Female       Liam      Brown
# 9999   327.099675  38.231999      92.448409    Male       Nina  Rodriguez
#
#                            hospital       treatment  \
# 9995          Hilltop Health Center      Counseling
# 9996  Silver Springs Medical Center      Counseling
# 9997           Forest View Hospital      Medication
# 9998           Valley View Hospital  Rehabilitation
# 9999          Mountainview Hospital   Physiotherapy
#
#                      treatment_date  heart_disease
# 9995  2021-05-26 19:33:42.294716670              1
# 9996  2023-01-18 14:03:48.063824549              0
# 9997  2019-01-15 15:20:39.564981948              0
# 9998  2018-11-20 05:42:20.533769288              1
# 9999  2019-10-14 16:11:35.683316170              1

# %%
df.sample(10)
# Out:
#            full_name  age country         state  blood_pressure  cholesterol  \
# 2160     Frank Smith   46     USA         Maine      148.549979   319.356440
# 2439    Oliver Davis   54     USA      Colorado       90.682854   234.766910
# 6741      Eva Miller   64     USA  North Dakota      109.055845   155.210209
# 9088   Hannah Garcia   44     USA          Utah      109.203121   116.210108
# 4430  David Williams   55     USA        Nevada      116.657913   197.750872
# 7419     Kelly Jones   29     USA      Nebraska      102.328179   166.909243
# 2026  Isaac Williams   32     USA       Montana       61.732891   109.274034
# 2792    Hannah Smith   77     USA     Wisconsin       50.649609   150.785379
# 7124  Kelly Martinez   25     USA       Indiana       91.231151   241.726594
# 5048   Eva Rodriguez   61     USA      Illinois       86.302815   125.284582
#
#             bmi  glucose_level  gender first_name  last_name  \
# 2160  38.519738      35.375053    Male      Frank      Smith
# 2439   9.345542     189.778955  Female     Oliver      Davis
# 6741  29.372051     159.518254  Female        Eva     Miller
# 9088  26.497417      27.352877  Female     Hannah     Garcia
# 4430  13.717772     120.662777    Male      David   Williams
# 7419   9.978749     -64.053279  Female      Kelly      Jones
# 2026  14.694346     277.062121  Female      Isaac   Williams
# 2792  15.942264      58.856492    Male     Hannah      Smith
# 7124   0.275823     136.261990  Female      Kelly   Martinez
# 5048  10.897464     253.924854  Female        Eva  Rodriguez
#
#                            hospital       treatment  \
# 2160          Mountainview Hospital         Surgery
# 2439           Forest View Hospital      Counseling
# 6741        Heritage Medical Center      Counseling
# 9088       Crossroads Health Center         Surgery
# 4430          Hilltop Health Center  Rehabilitation
# 7419  Clearwater Community Hospital  Rehabilitation
# 2026       Sunnydale Medical Center      Counseling
# 2792       Crossroads Health Center      Counseling
# 7124           Cedar Creek Hospital      Counseling
# 5048          Hilltop Health Center         Surgery
#
#                      treatment_date  heart_disease
# 2160  2018-10-13 17:13:23.088935810              1
# 2439  2022-07-04 02:04:41.216363309              0
# 6741  2018-07-16 11:43:35.746933745              1
# 9088  2022-07-11 15:51:55.643257474              0
# 4430  2022-10-27 09:41:05.755579863              1
# 7419  2018-05-01 15:53:01.265219413              0
# 2026  2022-09-18 08:29:58.054604917              1
# 2792  2022-07-30 17:37:07.684398539              0
# 7124  2020-03-15 17:28:06.911260815              0
# 5048  2022-02-24 01:15:39.038460788              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   full_name       10000 non-null  object
#  1   age             10000 non-null  int64
#  2   country         10000 non-null  object
#  3   state           10000 non-null  object
#  4   blood_pressure  10000 non-null  float64
#  5   cholesterol     10000 non-null  float64
#  6   bmi             10000 non-null  float64
#  7   glucose_level   10000 non-null  float64
#  8   gender          10000 non-null  object
#  9   first_name      10000 non-null  object
#  10  last_name       10000 non-null  object
#  11  hospital        10000 non-null  object
#  12  treatment       10000 non-null  object
#  13  treatment_date  10000 non-null  object
#  14  heart_disease   10000 non-null  int64
# dtypes: float64(4), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
df.isnull()
# Out:
#       full_name    age  country  state  blood_pressure  cholesterol    bmi  \
# 0         False  False    False  False           False        False  False
# 1         False  False    False  False           False        False  False
# 2         False  False    False  False           False        False  False
# 3         False  False    False  False           False        False  False
# 4         False  False    False  False           False        False  False
# ...         ...    ...      ...    ...             ...          ...    ...
# 9995      False  False    False  False           False        False  False
# 9996      False  False    False  False           False        False  False
# 9997      False  False    False  False           False        False  False
# 9998      False  False    False  False           False        False  False
# 9999      False  False    False  False           False        False  False
#
#       glucose_level  gender  first_name  last_name  hospital  treatment  \
# 0             False   False       False      False     False      False
# 1             False   False       False      False     False      False
# 2             False   False       False      False     False      False
# 3             False   False       False      False     False      False
# 4             False   False       False      False     False      False
# ...             ...     ...         ...        ...       ...        ...
# 9995          False   False       False      False     False      False
# 9996          False   False       False      False     False      False
# 9997          False   False       False      False     False      False
# 9998          False   False       False      False     False      False
# 9999          False   False       False      False     False      False
#
#       treatment_date  heart_disease
# 0              False          False
# 1              False          False
# 2              False          False
# 3              False          False
# 4              False          False
# ...              ...            ...
# 9995           False          False
# 9996           False          False
# 9997           False          False
# 9998           False          False
# 9999           False          False
#
# [10000 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# full_name         0
# age               0
# country           0
# state             0
# blood_pressure    0
# cholesterol       0
# bmi               0
# glucose_level     0
# gender            0
# first_name        0
# last_name         0
# hospital          0
# treatment         0
# treatment_date    0
# heart_disease     0
# dtype: int64

# %%
df['treatment'].value_counts()
# Out:
# treatment
# Counseling        2084
# Medication        2011
# Surgery           2003
# Physiotherapy     1952
# Rehabilitation    1950
# Name: count, dtype: int64

# %%
df=df.drop(columns=['full_name','country','hospital'])

# %%
df=df.drop(columns=['treatment'])

# %%
df.head()
# Out:
#    age          state  blood_pressure  cholesterol        bmi  glucose_level  \
# 0   21           Utah      138.068129   270.564349  36.101427      63.487954
# 1   44   North Dakota      100.383639   160.910030  14.330471     187.008977
# 2   22           Iowa      145.618318   208.490251  20.277098      35.903576
# 3   19      Louisiana      152.577870   348.153738  62.712693      31.495166
# 4   64  Massachusetts      111.793570   200.628925  14.468485     154.513129
#
#    gender first_name last_name                 treatment_date  heart_disease
# 0  Female      Alice   Johnson  2021-07-07 21:23:23.542872956              1
# 1  Female        Bob  Williams  2023-09-13 07:31:37.167014532              0
# 2  Female     Oliver     Jones  2019-11-22 03:56:29.389793943              0
# 3  Female      Quinn     Davis  2021-10-09 23:10:16.253672680              1
# 4  Female      Alice  Martinez  2018-03-16 04:43:59.950843739              1

# %%
df.head()
# Out:
#    age  blood_pressure  cholesterol        bmi  glucose_level  gender  \
# 0   21      138.068129   270.564349  36.101427      63.487954  Female
# 1   44      100.383639   160.910030  14.330471     187.008977  Female
# 2   22      145.618318   208.490251  20.277098      35.903576  Female
# 3   19      152.577870   348.153738  62.712693      31.495166  Female
# 4   64      111.793570   200.628925  14.468485     154.513129  Female
#
#                   treatment_date  heart_disease
# 0  2021-07-07 21:23:23.542872956              1
# 1  2023-09-13 07:31:37.167014532              0
# 2  2019-11-22 03:56:29.389793943              0
# 3  2021-10-09 23:10:16.253672680              1
# 4  2018-03-16 04:43:59.950843739              1

# %%
df=df.drop(columns=['treatment_date'])

# %%
df.head()
# Out:
#    age  blood_pressure  cholesterol        bmi  glucose_level  gender  \
# 0   21      138.068129   270.564349  36.101427      63.487954  Female
# 1   44      100.383639   160.910030  14.330471     187.008977  Female
# 2   22      145.618318   208.490251  20.277098      35.903576  Female
# 3   19      152.577870   348.153738  62.712693      31.495166  Female
# 4   64      111.793570   200.628925  14.468485     154.513129  Female
#
#    heart_disease
# 0              1
# 1              0
# 2              0
# 3              1
# 4              1

# %%
df.shape
# Out:
# (10000, 7)

# %%
df['gender']=df['gender'].replace({"Male":0,"Female":1})
df.head()
# Out:
#    age  blood_pressure  cholesterol        bmi  glucose_level  gender  \
# 0   21      138.068129   270.564349  36.101427      63.487954       1
# 1   44      100.383639   160.910030  14.330471     187.008977       1
# 2   22      145.618318   208.490251  20.277098      35.903576       1
# 3   19      152.577870   348.153738  62.712693      31.495166       1
# 4   64      111.793570   200.628925  14.468485     154.513129       1
#
#    heart_disease
# 0              1
# 1              0
# 2              0
# 3              1
# 4              1

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(columns=['heart_disease'])
y=df['heart_disease']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score=accuracy_score(y_pred,y_test)
print(score)
# Out:
# 0.925

# %%
parameter = {
    'criterion': ['gini','entropy'],
    'max_depth': [7,9,11],
    'min_samples_split': [5,10,20],
    'splitter':['best','random'],
    'min_samples_leaf': [2,4,6],
    'max_features':['auto', 'sqrt', 'log2']
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
cv=GridSearchCV(clf,param_grid=parameter,cv=5,scoring='accuracy')

# %%
cv.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 540 fits failed out of a total of 1620.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 540 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [     nan      nan      nan      nan      nan      nan      nan      nan
#       nan      nan      nan      nan      nan      nan      nan      nan
#       nan      nan 0.867625 0.73075  0.85925  0.73525  0.88025  0.74025
#  0.84475  0.752875 0.852    0.726    0.8495   0.7215   0.842625 0.71
#  0.8515   0.7475   0.86025  0.72     0.84675  0.75575  0.83425  0.77375
#  0.87425  0.703375 0.871875 0.758625 0.858625 0.7145   0.868875 0.707625
#  0.866625 0.7105   0.8995   0.7675   0.81825  0.736375      nan      nan
#       nan      nan      nan      nan      nan      nan      nan      nan
#       nan      nan      nan      nan      nan      nan      nan      nan
#  0.869625 0.7875   0.895375 0.7765   0.872625 0.774875 0.9045   0.72175
#  0.8915   0.81075  0.89475  0.7305   0.88975  0.717625 0.88475  0.75425
#  0.9035   0.74725  0.878625 0.77025  0.906    0.8075   0.876125 0.784625
#  0.857    0.7625   0.891    0.7775   0.899    0.7805   0.882125 0.72525
#  0.857875 0.767625 0.89425  0.765375      nan      nan      nan      nan
#       nan      nan      nan      nan      nan      nan      nan      nan
#       nan      nan      nan      nan      nan      nan 0.899375 0.791
#  0.908125 0.830875 0.8815   0.796625 0.906125 0.78325  0.901875 0.830125
#  0.903625 0.776875 0.90075  0.7945   0.904    0.8085   0.886625 0.7635
#  0.910875 0.78825  0.88725  0.808    0.905625 0.796625 0.9035   0.78875
#  0.90075  0.8085   0.901875 0.74425  0.8935   0.805    0.90175  0.8265
#  0.895625 0.824375      nan      nan      nan      nan      nan      nan
#       nan      nan      nan      nan      nan      nan      nan      nan
#       nan      nan      nan      nan 0.8725   0.74825  0.848375 0.745375
#  0.892    0.722125 0.810625 0.779875 0.878    0.73425  0.854875 0.708
#  0.857125 0.7455   0.879625 0.74625  0.861375 0.68175  0.842375 0.72975
#  0.892    0.7615   0.897375 0.725875 0.87     0.735625 0.864    0.720625
#  0.87975  0.745875 0.873625 0.707375 0.8235   0.734375 0.875    0.71925
#       nan      nan      nan      nan      nan      nan      nan      nan
#       nan      nan      nan      nan      nan      nan      nan      nan
#       nan      nan 0.870875 0.7665   0.901875 0.776875 0.883375 0.7875
#  0.904375 0.775375 0.8705   0.764625 0.90475  0.748375 0.888    0.8095
#  0.885125 0.668125 0.903875 0.7265   0.87875  0.79625  0.897875 0.7205
#  0.866375 0.694625 0.838375 0.753125 0.897    0.783375 0.88525  0.77275
#  0.896125 0.766375 0.879    0.790875 0.88975  0.76125       nan      nan
#       nan      nan      nan      nan      nan      nan      nan      nan
#       nan      nan      nan      nan      nan      nan      nan      nan
#  0.905625 0.814375 0.901875 0.823125 0.90325  0.7885   0.907625 0.779875
#  0.90375  0.808125 0.8845   0.79025  0.9055   0.7905   0.88575  0.733625
#  0.894125 0.76825  0.90225  0.7915   0.89025  0.842625 0.893625 0.816
#  0.904    0.77075  0.89225  0.78325  0.905125 0.799    0.8995   0.802375
#  0.89375  0.716125 0.885875 0.7935  ]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [7, 9, 11],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [2, 4, 6],
#                          'min_samples_split': [5, 10, 20],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
cv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 11,
#  'max_features': 'log2',
#  'min_samples_leaf': 2,
#  'min_samples_split': 5,
#  'splitter': 'best'}

# %%
y_test
# Out:
# 143     1
# 2348    0
# 6088    1
# 1621    1
# 5493    0
#        ..
# 9478    1
# 7638    1
# 1227    0
# 2054    1
# 9649    1
# Name: heart_disease, Length: 2000, dtype: int64

# %%
y_pred=cv.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
score=accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.912

# %%
y_train_pred = cv.predict(X_train)
y_test_pred = cv.predict(X_test)

# Compute accuracy
train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

print(f"Train Accuracy: {train_acc*100:.2f}%")
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Train Accuracy: 93.05%
# Test Accuracy: 91.20%

# %%
from sklearn.ensemble import RandomForestClassifier
